# %%
import pandas as pd
import datamol as dm
from tqdm.auto import tqdm
from rdkit.Chem import rdDepictor
import mols2grid

# %%
df_2 = pd.read_csv('E:\\Machine Learning\\Cheminformatics\\CompoundDataAcquisition\\table_3.csv', index_col='Unnamed: 0')

# %%
df_2
# Out:
#         pIC50                                preprocessed_smiles  \
# 0    9.522879           OCCN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1
# 1    8.958607  CC(C)(C)[C@]1(O)CCN2C[C@H]3c4ccccc4CCc4cccc(c4...
# 2    8.958607  CC(C)(C)[C@]1(O)CCN2C[C@@H]3c4ccccc4CCc4cccc(c...
# 3    8.896196    O=C(CCCN1CCC2(CC1)C(=O)NCN2c1ccccc1)c1ccc(F)cc1
# 4    8.831503  CC(C)[C@@]1(NC(=O)C2C[C@@H]3c4cccc5[nH]cc(c45)...
# ..        ...                                                ...
# 288  4.775726  Cc1c(C)c2c(c(C)c1O)CCC(C)(CN1CCN(c3cc(N4CCCC4)...
# 289  4.700014   CCCCc1oc2ccccc2c1C(=O)c1cc(I)c(OCCN(CC)CC)c(I)c1
# 290  4.637932                         CCN(CC)C(=S)SSC(=S)N(CC)CC
# 291  4.619789                              CNC[C@@H]1OCCc2ccsc21
# 292  4.000000                                  NCCc1ccc(O)c(O)c1
#
#      molecular_weight  n_hba  n_hbd     logp  Lipinski_pass
# 0          403.148511      5      1  3.94270           True
# 1          361.240565      2      1  4.84480           True
# 2          361.240565      2      1  4.84480           True
# 3          395.200905      4      1  3.21710           True
# 4          611.310769      6      3  2.71720           True
# ..                ...    ...    ...      ...            ...
# 288        520.352575      8      1  4.21376           True
# 289        645.023690      4      0  6.93620          False
# 290        296.050933      4      0  3.62120           True
# 291        183.071785      3      1  1.58130           True
# 292        153.078979      3      3  0.59900           True
#
# [293 rows x 7 columns]

# %%
df = df_2.copy()
df = df[df["Lipinski_pass"]==True].reset_index()
df['Lipinski_pass'].value_counts()
# Out:
# True    260
# Name: Lipinski_pass, dtype: int64

# %% [markdown]
# The following part of the notebook was inspired by a useful post by Pat Walters

# %%
#generate RDKit mol object for prerprocessed smiles
df['romol'] = dm.from_df(df, smiles_column = "preprocessed_smiles")

#cluster molecules
cluster_list = dm.cluster_mols(df.romol)

cluster_idx = [-1] * len(df)
for i, cluster in enumerate(tqdm(cluster_list[0])):
    #use Bemis-Murcko framework to align structures in each cluster 
    dm.align.auto_align_many([df.romol.values[x] for x in cluster],copy=False,partition_method='cluster', cluster_cutoff = 0.70)
    for c in cluster:
        cluster_idx[c] = i

df['cluster_idx'] = cluster_idx
# Out:
#   0%|          | 0/242 [00:00<?, ?it/s]

# %%
cluster_sample_df = df.sort_values("cluster_idx").drop_duplicates("cluster_idx").copy()
cluster_sample_df
# Out:
#      index     pIC50                                preprocessed_smiles  \
# 107    112  6.853872  CCOc1ccccc1N1CCN(CCCC(=O)NCc2nc3ccc(F)cc3c(=O)...
# 84      88  7.136677    Cc1ccc(N2CCN(C[C@@H]3C[C@H]3c3ccccc3)CC2)c(C)c1
# 2        2  8.958607  CC(C)(C)[C@]1(O)CCN2C[C@@H]3c4ccccc4CCc4cccc(c...
# 201    215  5.823909  Cc1cccc(N2CCN(CCCC(=O)NCc3nc4cc(F)ccc4c(=O)n3-...
# 166    176  6.146971  CCCN(CCC)[C@@H]1Cc2cccc3c2n(c(=O)n3CCCCNC(=O)c...
# ..     ...       ...                                                ...
# 7        7  8.769551  CN(C)C(=O)N[C@H]1CC[C@H](CCN2CCN(c3cccc(Cl)c3C...
# 6        6  8.791559     OCCN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1
# 5        5  8.800794  CC(C)CC1C(=O)N2CCC[C@H]2[C@]2(O)O[C@](NC(=O)C3...
# 3        3  8.896196    O=C(CCCN1CCC2(CC1)C(=O)NCN2c1ccccc1)c1ccc(F)cc1
# 0        0  9.522879           OCCN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1
#
#      molecular_weight  n_hba  n_hbd     logp  Lipinski_pass  \
# 107        573.275133      8      1  4.15070           True
# 84         320.225249      2      0  4.22914           True
# 2          361.240565      2      1  4.84480           True
# 201        527.269654      6      1  4.36024           True
# 166        487.294725      5      2  4.54120           True
# ..                ...    ...    ...      ...            ...
# 7          426.195317      3      1  4.33550           True
# 6          437.174868      5      1  4.30810           True
# 5          653.221281      6      3  3.19280           True
# 3          395.200905      4      1  3.21710           True
# 0          403.148511      5      1  3.94270           True
#
#                                                  romol  cluster_idx
# 107  <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...            0
# 84   <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...            1
# 2    <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...            2
# 201  <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...            3
# 166  <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...            4
# ..                                                 ...          ...
# 7    <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...          237
# 6    <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...          238
# 5    <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...          239
# 3    <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...          240
# 0    <rdkit.Chem.rdchem.Mol object at 0x000001ABF30...          241
#
# [242 rows x 10 columns]
